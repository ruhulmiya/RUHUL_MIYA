# %%
import pandas as pd
df = pd.read_csv('/content/IPL.csv')
df
# Out:
#       id  season        city        date                  team1  \
# 0      1    2008   Bangalore  18-04-2008  Kolkata Knight Riders
# 1      2    2008  Chandigarh  19-04-2008    Chennai Super Kings
# 2      3    2008       Delhi  19-04-2008       Rajasthan Royals
# 3      4    2008      Mumbai  20-04-2008         Mumbai Indians
# 4      5    2008     Kolkata  20-04-2008        Deccan Chargers
# ..   ...     ...         ...         ...                    ...
# 572  573    2016      Raipur  22-05-2016       Delhi Daredevils
# 573  574    2016   Bangalore  24-05-2016          Gujarat Lions
# 574  575    2016       Delhi  25-05-2016    Sunrisers Hyderabad
# 575  576    2016       Delhi  27-05-2016          Gujarat Lions
# 576  577    2016   Bangalore  29-05-2016    Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# ...

# %%
missing_values = df.isnull().sum()
missing_values
# Out:
# id                   0
# season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               3
# win_by_runs          0
# win_by_wickets       0
# player_of_match      3
# venue                0
# umpire1              0
# umpire2              0
# umpire3            577
# dtype: int64

# %%
missing_values = df.notnull().sum()
missing_values
# Out:
# id                 577
# season             577
# city               570
# date               577
# team1              577
# team2              577
# toss_winner        577
# toss_decision      577
# result             577
# dl_applied         577
# winner             574
# win_by_runs        577
# win_by_wickets     577
# player_of_match    574
# venue              577
# umpire1            577
# umpire2            577
# umpire3              0
# dtype: int64

# %%
win_by_wickets = df["win_by_wickets"]
plt.plot(win_by_wickets,color = 'orange',label = 'win_by_wickets')
plt.legend()
plt.show()

# %%
sns.pairplot(df,hue='season')

# %%
#barplot
sns.barplot(x='season', y='winner',data=df)
# Out:
# <Axes: xlabel='season', ylabel='winner'>

# %%
sns.histplot(x = 'season',data = df)
# Out:
# <Axes: xlabel='season', ylabel='Count'>

# %%
#distribution plot
sns.displot(x = 'season',data = df)

# %%
#boxplot
sns.boxplot(df['winner'])
# Out:
# <Axes: ylabel='winner'>

# %%
sns.scatterplot(x = 'toss_decision',y = 'winner',data = df)
# Out:
# <Axes: xlabel='toss_decision', ylabel='winner'>

# %%
corr = df[['win_by_runs','season','win_by_wickets']].corr()
print(corr)
sns.heatmap(corr)
# Out:
#                 win_by_runs    season  win_by_wickets
# win_by_runs        1.000000 -0.018098       -0.572839
# season            -0.018098  1.000000       -0.005966
# win_by_wickets    -0.572839 -0.005966        1.000000
# <Axes: >
